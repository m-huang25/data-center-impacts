# %%
cd /home/user/Capstone/GitHub/data-center-impacts
# Out:
# /home/user/Capstone/GitHub/data-center-impacts

# %%
# !git -C /home/user/Capstone/GitHub rev-parse --show-toplevel
# Out:
# /home/user/Capstone

# %%
# %%bash
#
# # Go to the top-level of your repo
# cd /home/user/Capstone
#
# # Step 1: Commit any current changes to avoid a dirty working tree
# git add .
# git commit -m "Save current changes before cleaning history" || echo "No changes to commit"
#
# # Step 2: Remove the notebook with exposed GitHub token from all commits
# git filter-branch --force --index-filter \
#   "git rm --cached --ignore-unmatch GitHub/data-center-impacts/github_cocalc_sync_26-25-03.ipynb" \
#   --prune-empty --tag-name-filter cat -- --all
#
# # Step 3: Clean up temporary references and optimize repo
# rm -rf .git/refs/original/
# git reflog expire --expire=now --all
# git gc --prune=now --aggressive
#
# # Step 4: Force push the cleaned repo to GitHub
# git push --force --set-upstream origin main
# Out:
# ...
# hint: You've added another git reposit
# ory inside your current repository.
# hint: Clones of the outer repository will not contain the conten
# ts of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a
# submodule, use:
# hint:
# hint: 	git submodule add <url> data_center_research
# hint:
# hint: If you added
#  this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached da
# ta_center_research
# hint:
# hint: See "git help submodule" for more information.
# [main 5eb3f35] Save current changes before cleaning history
#  17 files changed, 1173 insertions(+), 1
# 201 deletions(-)
#  create mode 100644 GitHub/data-center-impacts/github_cocalc_sync_2026-27-03.ipynb
#  create mode 160000 data_center_research
#  delete mode 100644 data_center_research_r/.gitignore
#  dele
# te mode 100644 data_center_research_r/data/analysis/README.txt
#  delete mode 100644 data_center_resea
# ...
