# %%
# Create and navigate to a project directory

cd ~/Capstone/data_center_research

# List everything in the project folder
ls ~/Capstone/data_center_research
# Out:
# README.md  data  notebook  outputs  scripts

# %%
# Create root directory where Git repo will live
~/Capstone/data_center_research

#Initialize git inside ~/Capstone

git init
# Out:
# bash: /home/user/Capstone/data_center_research: Is a directory
# Reinitialized existing Git repository in /home/user/Capstone/data_center_research/.git/

# %%
# Add GitHub repo as a remote

git remote add origin https://github.com/m-huang25/data-center-impacts.git

# Verify that you added Gitub repo as a remote

git remote -v
# Out:
# error: remote origin already exists.
# origin	https://github.com/m-huang25/data-center-impacts.git (fetch)
# origin	https://github.com/m-huang25/data-center-impacts.git (push)

# %%
%%bash

# Add archive, data, docs, outputs and scripts folders only

git add data_center_research/archive
git add data_center_research/data
git add data_center_research/docs
git add data_center_research/outputs
git add data_center_research/scripts

# Commit the changes, create the root commit

git commit -m "Add archive, data, docs, outputs and scripts folders for data-center-impacts"

# git push -u origin main
# Out:
# bash: fg: %%bash: no such job
# [main feb2061] Add data and scripts folders for data-center-impacts
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# Check which branch in your GitHub repo your project folder went to 

git branch

# Check status

git status
# Out:
# * main
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.GitHub.ipynb.sage-jupyter2
# 	GitHub.ipynb
# nothing added to commit but untracked files present (use "git add" to track)

# %%
%%bash 
cd ~/Capstone/data_center_research

# Create .gitignore for project
cat > .gitignore << 'EOF'

    # Large data files
    *.nc
    *.hdf5
    *.tif
    *.geotiff
    data/raw/large/

    # Temporary files
    *.tmp
    *.temp
    ~*

    # Python
    __pycache__/
    *.py[cod]
    .ipynb_checkpoints/

    # R
    .Rhistory
    .RData
    .Rproj.user/

    # System files
    .DS_Store
    Thumbs.db 
EOF

# Add and commit .gitignore
git add .gitignore
git commit -m "Add .gitignore for environmental data science projects"


# view the file in the directory
echo "
The repo directory structure is now:

$(ls -la)"


# view the contents of this file (mimics the above code)
echo "
The .gitignore file contents now: 
$(cat .gitignore)"
# Out:
# bash: fg: %%bash: no such job
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	../..gitgnore.swp
# 	../.GitHub.ipynb.sage-jupyter2
# 	../.github.ipynb.sage-jupyter2
# 	../2025-11-24-file-1.term
# 	../GitHub.ipynb
# 	../github.ipynb
# nothing added to commit but untracked files present (use "git add" to track)
# The repo directory structure is now:
# total 6
# drwx------ 4 user user   5 Nov 25 02:40 .
# drwxr-xr-x 4 user user  10 Nov 25 02:39 ..
# -rw-r--r-- 1 user user 308 Nov 25 02:56 .gitignore
# drwxr-xr-x 8 user user   8 Nov 20 23:35 data
# drwxr-xr-x 2 user user   6 Nov 24 14:33 scripts
# The .gitignore file contents now:
#     # Large data files
#     *.nc
#     *.hdf5
#     *.tif
#     *.geotiff
#     data/raw/large/
#     # Temporary files
#     *.tmp
#     *.temp
#     ~*
#     # Python
#     __pycache__/
#     *.py[cod]
#     .ipynb_checkpoints/
#     # R
#     .Rhistory
#     .RData
#     .Rproj.user/
# ...

# %%
%%bash 
cd ~/Capstone/data_center_research

# Stage only data and script foldesr

git add data_center_research/data
git add data_center_research/scripts
# Out:
# bash: fg: %%bash: no such job
# ...
# fatal: pathspec 'data_center_research_r/data' did not match any files
# ...
# fatal: pathspec 'data_center_research_r/scripts' did not match any files
# : 128

# %%
%%bash

cd ~/Capstone

ls -R
# Out:
# bash: fg: %%bash: no such job
# .:
# 2025-11-24-file-1.term  GitHub.ipynb  data_center_research_r
# ./data_center_research_r:
# data  scripts
# ./data_center_research_r/data:
# analysis  archive  metadata  outputs  processed  raw_data
# ./data_center_research_r/data/analysis:
# README.txt
# ./data_center_research_r/data/archive:
# README.txt
# ./data_center_research_r/data/metadata:
# README.txt
# ./data_center_research_r/data/outputs:
# README.txt
# ./data_center_research_r/data/processed:
# README.txt
# ./data_center_research_r/data/raw_data:
# README.txt  issued_air_permits.csv  issued_air_permits.xlsx
# ./data_center_research_r/scripts:
# README.md  README.txt  air_quality_permits.ipynb
